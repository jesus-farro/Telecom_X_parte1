# %%
#Bibliotecas python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# ##**Extracción de los datos**

# %%
#path = 'https://github.com/ingridcristh/challenge2-data-science-LATAM/blob/main/TelecomX_Data.json'

# %%
#res = requests.get(path) #https://api.url.com/data
#df = pd.DataFrame(res.json())
